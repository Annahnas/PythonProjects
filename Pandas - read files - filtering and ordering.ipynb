# %% [raw]
# # Reading files

# %%
import pandas as pd

# %%
#shift + tab to see all the arguments
#import a csv file with your own header
pd.read_csv(r"/Users/annafall/Downloads/dirpython/companies.csv", header = None, names = ['Name', 'Industry'])
# Out:
#                                                                                                      Name  \
# Rank Name                     Industry                   Revenue (USD millions) Revenue growth  Employees
# 1    Walmart                  Retail                     611,289                6.7%            2,100,000
# 2    Amazon                   Retail and Cloud Computing 513,983                9.4%            1,540,000
# 3    Exxon Mobil              Petroleum industry         413,680                44.8%              62,000
# 4    Apple                    Electronics industry       394,328                7.8%              164,000
# ...                                                                                                   ...
# 96   Best Buy                 Retail                     46,298                 10.6%              71,100
# 97   Bristol-Myers Squibb     Pharmaceutical industry    46,159                 0.5%               34,300
# ...

# %%
df = pd.read_csv(r"/Users/annafall/Downloads/dirpython/companies.csv")
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and Cloud Computing
# 2      3               Exxon Mobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %%
#text file

df = pd.read_table(r"/Users/annafall/Downloads/dirpython/test.txt", sep =',')
df
# Out:
#    Rank                  Name                    Industry  \
# 0     1               Walmart                      Retail
# 1     2                Amazon  Retail and Cloud Computing
# 2     3           Exxon Mobil          Petroleum industry
# 3     4                 Apple        Electronics industry
# 4     5    UnitedHealth Group                  Healthcare
# 5     6            CVS Health                  Healthcare
# 6     7    Berkshire Hathaway                Conglomerate
# 7     8              Alphabet                  Technology
# 8     9  McKesson Corporation                      Health
# 9    10   Chevron Corporation          Petroleum industry
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 0                611,289           6.7%  2,100,000      Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000        Seattle, Washington
# 2                413,680          44.8%     62,000              Spring, Texas
# ...

# %%
#json file
df = pd.read_json(r"/Users/annafall/Downloads/dirpython/example.json")
df
# Out:
#                   version                                           examples
# SendSSHPublicKey        1  [{'input': {'AvailabilityZone': 'us-west-2a', ...

# %%
#excel file -- read the first sheet
df = pd.read_excel(r"/Users/annafall/Downloads/dirpython/csv files/Recurringfunctions.xlsx")
df
# Out:
#                                FUNCTION  \
# 0                  ReverseEveryTwoBytes
# 1             GetNbrFromIMSPartyAddress
# 2            GetCustAttrValueByAttrCode
# 3                 GetPPListIntersection
# 4                            ZoneToList
# 5              GetBalSumByAcctResIdList
# 6               JudgeCircleByUnitAndNum
# 7                          GetTimeOnNet
# 8                     BenefitNotifyPcrf
# 9              GetDepositByLevelAndCode
# 10                 JudgeGroup2GroupCall
# 11   GetCreditLimitRemainBeforeThisTime
# 12    GetCreditLimitRemainAfterThisTime
# 13                JudgeMainOfferIsEqual
# 14         GetRemainRatioOfBillingCycle
# 15                              Replace
# 16                   GetVirtualSubsAttr
# 17             GetChargedaysByStateList
# 18                SetCBECModifyAttrList
# 19                 GetOfferAttrValueSum
# 20                GetInstCntByOfferCode
# 21          JudgeAcctItemTypeInGlByCode
# ...

# %%
#excel file -- read the second sheet
df2 = pd.read_excel(r"/Users/annafall/Downloads/dirpython/csv files/Recurringfunctions.xlsx", sheet_name = 'Sheet2')
df2
# Out:
#      a    d   f
# 0  vgv  ffv  df

# %%
#SHOW ALL THE ROW DATA
pd.set_option('display.max.rows', 188)

# %%
#SHOW ALL THE COLOMN DATA
pd.set_option('display.max.colomns', 7)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       1 non-null      object
#  1   d       1 non-null      object
#  2   f       1 non-null      object
# dtypes: object(3)
# memory usage: 156.0+ bytes

# %%
df2.shape
# Out:
# (1, 3)

# %%
df2.head(2) #first row
# Out:
#      a    d   f
# 0  vgv  ffv  df

# %%
df2.tail(2) # last row
# Out:
#      a    d   f
# 0  vgv  ffv  df

# %%
df2['a']
# Out:
# 0    vgv
# Name: a, dtype: object

# %%
df2.loc[0]
# Out:
# a    vgv
# d    ffv
# f     df
# Name: 0, dtype: object

# %%
df2.iloc[0] #look at the integer location
# Out:
# a    vgv
# d    ffv
# f     df
# Name: 0, dtype: object

# %% [markdown]
# # Filtering and ordering

# %%
import pandas as pd

# %%
df = pd.read_csv(r"/Users/annafall/Downloads/dirpython/companies.csv")
df
# Out:
#     Rank                                 Name  \
# 0      1                              Walmart
# 1      2                               Amazon
# 2      3                          Exxon Mobil
# 3      4                                Apple
# 4      5                   UnitedHealth Group
# 5      6                           CVS Health
# 6      7                   Berkshire Hathaway
# 7      8                             Alphabet
# 8      9                 McKesson Corporation
# 9     10                  Chevron Corporation
# 10    11                    AmerisourceBergen
# 11    12                               Costco
# 12    13                            Microsoft
# 13    14                      Cardinal Health
# 14    15                                Cigna
# 15    16                   Marathon Petroleum
# 16    17                          Phillips 66
# 17    18                        Valero Energy
# 18    19                   Ford Motor Company
# ...

# %%
df[df['Rank'] <= 10]
# Out:
#    Rank                  Name                    Industry  \
# 0     1               Walmart                      Retail
# 1     2                Amazon  Retail and Cloud Computing
# 2     3           Exxon Mobil          Petroleum industry
# 3     4                 Apple        Electronics industry
# 4     5    UnitedHealth Group                  Healthcare
# 5     6            CVS Health                  Healthcare
# 6     7    Berkshire Hathaway                Conglomerate
# 7     8              Alphabet                  Technology
# 8     9  McKesson Corporation                      Health
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 0                611,289           6.7%  2,100,000      Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000        Seattle, Washington
# 2                413,680          44.8%     62,000              Spring, Texas
# ...

# %%
specific_companies =['Walmart', 'Apple']

df[df['Name'].isin(specific_companies)]
# Out:
#    Rank     Name              Industry Revenue (USD millions) Revenue growth  \
# 0     1  Walmart                Retail                611,289           6.7%
# 3     4    Apple  Electronics industry                394,328           7.8%
#
#    Employees           Headquarters
# 0  2,100,000  Bentonville, Arkansas
# 3    164,000  Cupertino, California

# %%
df[df['Name'].str.contains('Health')]
# Out:
#     Rank                Name    Industry Revenue (USD millions)  \
# 4      5  UnitedHealth Group  Healthcare                324,162
# 5      6          CVS Health  Healthcare                322,467
# 13    14     Cardinal Health  Healthcare                181,364
# 21    22     Elevance Health  Healthcare                156,595
# 67    68      HCA Healthcare  Healthcare                 60,233
#
#    Revenue growth Employees              Headquarters
# 4           12.7%   400,000     Minnetonka, Minnesota
# 5           10.4%   259,500  Woonsocket, Rhode Island
# 13          11.6%    46,035              Dublin, Ohio
# 21          13.0%   102,200     Indianapolis, Indiana
# 67           2.5%   250,500      Nashville, Tennessee

# %%
df2 = df.set_index('Name')
df2
# Out:
#                                      Rank                          Industry  \
# Name
# Walmart                                 1                            Retail
# Amazon                                  2        Retail and Cloud Computing
# Exxon Mobil                             3                Petroleum industry
# Apple                                   4              Electronics industry
# UnitedHealth Group                      5                        Healthcare
# CVS Health                              6                        Healthcare
# Berkshire Hathaway                      7                      Conglomerate
# Alphabet                                8                        Technology
# McKesson Corporation                    9                            Health
# Chevron Corporation                    10                Petroleum industry
# AmerisourceBergen                      11           Pharmaceutical industry
# ...

# %%
df2.filter(items = ['Industry', 'Employees', 'Revenue growth'], axis=1)
# Out:
#                                                              Industry  \
# Name
# Walmart                                                        Retail
# Amazon                                     Retail and Cloud Computing
# Exxon Mobil                                        Petroleum industry
# Apple                                            Electronics industry
# UnitedHealth Group                                         Healthcare
# CVS Health                                                 Healthcare
# Berkshire Hathaway                                       Conglomerate
# Alphabet                                                   Technology
# McKesson Corporation                                           Health
# Chevron Corporation                                Petroleum industry
# AmerisourceBergen                             Pharmaceutical industry
# Costco                                                         Retail
# ...

# %%
df2.filter(items = ['Walmart'], axis=0)
# Out:
#          Rank Industry Revenue (USD millions) Revenue growth  Employees  \
# Name
# Walmart     1   Retail                611,289           6.7%  2,100,000
#
#                   Headquarters
# Name
# Walmart  Bentonville, Arkansas

# %%
df2.filter(like = 'Health', axis=0)
# Out:
#                     Rank    Industry Revenue (USD millions) Revenue growth  \
# Name
# UnitedHealth Group     5  Healthcare                324,162          12.7%
# CVS Health             6  Healthcare                322,467          10.4%
# Cardinal Health       14  Healthcare                181,364          11.6%
# Elevance Health       22  Healthcare                156,595          13.0%
# HCA Healthcare        68  Healthcare                 60,233           2.5%
#
#                    Employees              Headquarters
# Name
# UnitedHealth Group   400,000     Minnetonka, Minnesota
# CVS Health           259,500  Woonsocket, Rhode Island
# Cardinal Health       46,035              Dublin, Ohio
# Elevance Health      102,200     Indianapolis, Indiana
# HCA Healthcare       250,500      Nashville, Tennessee

# %%
df2.loc['CVS Health']
# Out:
# Rank                                             6
# Industry                                Healthcare
# Revenue (USD millions)                     322,467
# Revenue growth                               10.4%
# Employees                                  259,500
# Headquarters              Woonsocket, Rhode Island
# Name: CVS Health, dtype: object

# %%
df2.iloc[6]
# Out:
# Rank                                    7
# Industry                     Conglomerate
# Revenue (USD millions)            302,089
# Revenue growth                       9.4%
# Employees                         383,000
# Headquarters              Omaha, Nebraska
# Name: Berkshire Hathaway, dtype: object

# %%
df[df['Rank'] < 10].sort_values(by = ['Rank', 'Industry'], ascending=False)
# Out:
#    Rank                  Name                    Industry  \
# 8     9  McKesson Corporation                      Health
# 7     8              Alphabet                  Technology
# 6     7    Berkshire Hathaway                Conglomerate
# 5     6            CVS Health                  Healthcare
# 4     5    UnitedHealth Group                  Healthcare
# 3     4                 Apple        Electronics industry
# 2     3           Exxon Mobil          Petroleum industry
# 1     2                Amazon  Retail and Cloud Computing
# 0     1               Walmart                      Retail
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 8                276,711           4.8%     48,500              Irving, Texas
# 7                282,836           9.8%    156,000  Mountain View, California
# 6                302,089           9.4%    383,000            Omaha, Nebraska
# ...

# %%
# Indexing

# %%
import pandas as pd

# %%
df = pd.read_csv(r"/Users/annafall/Downloads/dirpython/companies.csv")
df
# Out:
#     Rank                                 Name  \
# 0      1                              Walmart
# 1      2                               Amazon
# 2      3                          Exxon Mobil
# 3      4                                Apple
# 4      5                   UnitedHealth Group
# 5      6                           CVS Health
# 6      7                   Berkshire Hathaway
# 7      8                             Alphabet
# 8      9                 McKesson Corporation
# 9     10                  Chevron Corporation
# 10    11                    AmerisourceBergen
# 11    12                               Costco
# 12    13                            Microsoft
# 13    14                      Cardinal Health
# 14    15                                Cigna
# 15    16                   Marathon Petroleum
# 16    17                          Phillips 66
# 17    18                        Valero Energy
# 18    19                   Ford Motor Company
# ...

# %%
df = pd.read_csv(r"/Users/annafall/Downloads/dirpython/companies.csv", index_col="Name")
df
# Out:
#                                      Rank                          Industry  \
# Name
# Walmart                                 1                            Retail
# Amazon                                  2        Retail and Cloud Computing
# Exxon Mobil                             3                Petroleum industry
# Apple                                   4              Electronics industry
# UnitedHealth Group                      5                        Healthcare
# CVS Health                              6                        Healthcare
# Berkshire Hathaway                      7                      Conglomerate
# Alphabet                                8                        Technology
# McKesson Corporation                    9                            Health
# Chevron Corporation                    10                Petroleum industry
# AmerisourceBergen                      11           Pharmaceutical industry
# ...

# %%
df.reset_index(inplace=True) #revert

# %%
df.set_index('Name', inplace = True)
df
# Out:
#                                      Rank                          Industry  \
# Name
# Walmart                                 1                            Retail
# Amazon                                  2        Retail and Cloud Computing
# Exxon Mobil                             3                Petroleum industry
# Apple                                   4              Electronics industry
# UnitedHealth Group                      5                        Healthcare
# CVS Health                              6                        Healthcare
# Berkshire Hathaway                      7                      Conglomerate
# Alphabet                                8                        Technology
# McKesson Corporation                    9                            Health
# Chevron Corporation                    10                Petroleum industry
# AmerisourceBergen                      11           Pharmaceutical industry
# ...

# %%
df.loc['Amazon'] #search with string
# Out:
# Rank                                               2
# Industry                  Retail and Cloud Computing
# Revenue (USD millions)                       513,983
# Revenue growth                                  9.4%
# Employees                                  1,540,000
# Headquarters                     Seattle, Washington
# Name: Amazon, dtype: object

# %%
df.iloc[1] #search with integer
# Out:
# Rank                                               2
# Industry                  Retail and Cloud Computing
# Revenue (USD millions)                       513,983
# Revenue growth                                  9.4%
# Employees                                  1,540,000
# Headquarters                     Seattle, Washington
# Name: Amazon, dtype: object

# %%
df.reset_index(inplace = True)

# %%
df.set_index(['Name', 'Industry'], inplace = True)

# %%
df
# Out:
#                                                                       Rank  \
# Name                                Industry
# Walmart                             Retail                               1
# Amazon                              Retail and Cloud Computing           2
# Exxon Mobil                         Petroleum industry                   3
# Apple                               Electronics industry                 4
# UnitedHealth Group                  Healthcare                           5
# CVS Health                          Healthcare                           6
# Berkshire Hathaway                  Conglomerate                         7
# Alphabet                            Technology                           8
# McKesson Corporation                Health                               9
# Chevron Corporation                 Petroleum industry                  10
# AmerisourceBergen                   Pharmaceutical industry             11
# ...

# %%
#df.sort_index(ascending = [False, True])
df.sort_index()
#pd.set_option('display.max.columns', 188)
# Out:
#                                                                       Rank  \
# Name                                Industry
# AIG                                 Insurance                           78
# AT&T                                Conglomerate                        30
# AbbVie                              Pharmaceutical industry             75
# Albertsons                          Retail                              53
# Allstate                            Insurance                           86
# Alphabet                            Technology                           8
# Amazon                              Retail and Cloud Computing           2
# American Airlines                   Airline                             91
# American Express                    Financial                           79
# AmerisourceBergen                   Pharmaceutical industry             11
# Apple                               Electronics industry                 4
# ...

# %%
df.loc['Apple', 'Electronics industry'] #as we have 2 index, need to seach based on both
# Out:
# Rank                                          4
# Revenue (USD millions)                  394,328
# Revenue growth                             7.8%
# Employees                               164,000
# Headquarters              Cupertino, California
# Name: (Apple, Electronics industry), dtype: object

# %% [markdown]
# # Group By and Aggregating

# %%
import pandas as pd

# %%
df = pd.read_csv(r"/Users/annafall/Downloads/dirpython/Flavors.csv")
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
group_by_frame = df.groupby('Base Flavor') #group the base flavor

# %%
group_by_frame.mean() #the mean value for each base flavor
# Out:
# /var/folders/dp/9y872kks10d_3j3_9k946r_w0000gn/T/ipykernel_35541/4024548864.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_by_frame.mean()
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
df.groupby('Base Flavor').mean()
# Out:
# /var/folders/dp/9y872kks10d_3j3_9k946r_w0000gn/T/ipykernel_35541/2409314591.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Base Flavor').mean()
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
df.groupby('Base Flavor').count()
# Out:
#              Flavor  Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate         3      3              3               3             3
# Vanilla           6      6              6               6             6

# %%
df.groupby('Base Flavor').min()
# Out:
#                   Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate      Chocolate   Yes            8.2             7.0          15.2
# Vanilla      Cake Batter    No            2.3             3.4           5.7

# %%
df.groupby('Base Flavor').max()
# Out:
#                  Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate    Rocky Road   Yes            8.8             7.6          16.6
# Vanilla         Vanilla   Yes           10.0             8.0          18.0

# %%
df.groupby('Base Flavor').sum()
# Out:
# /var/folders/dp/9y872kks10d_3j3_9k946r_w0000gn/T/ipykernel_35541/1221781544.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Base Flavor').sum()
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate             25.2            21.7          47.1
# Vanilla               34.2            33.9          68.1

# %%
df.groupby('Base Flavor').agg({'Flavor Rating':['mean', 'max', 'count', 'sum'], 'Texture Rating':['mean', 'max', 'count', 'sum']})
# Out:
#             Flavor Rating                   Texture Rating
#                      mean   max count   sum           mean  max count   sum
# Base Flavor
# Chocolate             8.4   8.8     3  25.2       7.233333  7.6     3  21.7
# Vanilla               5.7  10.0     6  34.2       5.650000  8.0     6  33.9

# %%
df.groupby(['Base Flavor', 'Liked']).mean()
# Out:
# /var/folders/dp/9y872kks10d_3j3_9k946r_w0000gn/T/ipykernel_35541/1262277809.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Base Flavor', 'Liked']).mean()
#                    Flavor Rating  Texture Rating  Total Rating
# Base Flavor Liked
# Chocolate   Yes              8.4        7.233333     15.700000
# Vanilla     No               3.6        4.466667      8.066667
#             Yes              7.8        6.833333     14.633333

# %%
df.groupby(['Base Flavor', 'Liked']).agg({'Flavor Rating':['mean', 'max', 'count', 'sum']})
# Out:
#                   Flavor Rating
#                            mean   max count   sum
# Base Flavor Liked
# Chocolate   Yes             8.4   8.8     3  25.2
# Vanilla     No              3.6   4.7     3  10.8
#             Yes             7.8  10.0     3  23.4

# %%
df.groupby('Base Flavor').describe()
# Out:
#             Flavor Rating                                             \
#                     count mean       std  min    25%  50%  75%   max
# Base Flavor
# Chocolate             3.0  8.4  0.346410  8.2  8.200  8.2  8.5   8.8
# Vanilla               6.0  5.7  2.710719  2.3  4.025  5.6  6.8  10.0
#
#             Texture Rating            ...             Total Rating         \
#                      count      mean  ...    75%  max        count   mean
# Base Flavor                           ...
# Chocolate              3.0  7.233333  ...  7.350  7.6          3.0  15.70
# Vanilla                6.0  5.650000  ...  6.375  8.0          6.0  11.35
#
#
#                   std   min     25%   50%     75%   max
# Base Flavor
# Chocolate    0.781025  15.2  15.250  15.3  15.950  16.6
# Vanilla      4.263684   5.7   9.025  11.1  13.175  18.0
#
# [2 rows x 24 columns]
